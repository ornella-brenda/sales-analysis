# %% [markdown]
# # Sales analysis

# %% [markdown]
# ## Chargement des données

# %%
#librairies
import numpy as np
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# lecture de la base de données provenant du chemin dans lequel se trouve la BD ou les fichiers de la BD
files=[file for file in os.listdir(r'C:/Users/user/projet perso/BD')]
for file in files:
    print(file)
# Out:
# Sales_April_2019.csv
# Sales_August_2019.csv
# Sales_December_2019.csv
# Sales_February_2019.csv
# Sales_January_2019.csv
# Sales_July_2019.csv
# Sales_June_2019.csv
# Sales_March_2019.csv
# Sales_May_2019.csv
# Sales_November_2019.csv
# Sales_October_2019.csv
# Sales_September_2019.csv

# %%
#Regrouper les fichiers csv et creer une seule base de données qui sera utilisée par la suite 
# les différents fichiers ont été concatenés
path=r'C:\Users\user\projet perso\BD'
#Creer une nouvelle BD issue des fichiers de la premiere BD
data=pd.DataFrame()
for file in files:
    current_data=pd.read_csv(path+'/'+file)
    data=pd.concat([data,current_data])
data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %%
data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %% [markdown]
# ## Exploration des données

# %%
#Nombres de lignes et de colonnes
data.shape
# Out:
# (186850, 6)

# %%
#infos sur le jeu de données
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186850 entries, 0 to 11685
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 10.0+ MB

# %%
#voir les valeurs manquantes dans le dataset
data.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %% [markdown]
# ## Nettoyage des données

# %%
data.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
# Calculer le nombre de valeurs manquantes dans chaque colonne
missing_values_count = data.isnull().sum()

# Calculer le pourcentage de valeurs manquantes dans chaque colonne
percentage_missing_values = (missing_values_count / len(data)) * 100

# Afficher les résultats
print(percentage_missing_values)
# Out:
# Order ID            0.291678
# Product             0.291678
# Quantity Ordered    0.291678
# Price Each          0.291678
# Order Date          0.291678
# Purchase Address    0.291678
# dtype: float64

# %%
# suppression des valeurs manquantes
data=data.dropna(how='all')
data.shape
# Out:
# (186305, 6)

# %%
data.shape
# Out:
# (186305, 6)

# %%
#replace "Price each" by NA in price column
data['Price Each'].replace('Price Each',np.nan,inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13660\1197340799.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Price Each'].replace('Price Each',np.nan,inplace=True)

# %%
# conversion de la colonne prix en float

data['Price Each']=data['Price Each'].astype('float64')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13660\527589191.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Price Each']=data['Price Each'].astype('float64')

# %%
#replace "Quantity Ordered" by NA in quantity order  column
data['Quantity Ordered'].replace('Quantity Ordered',np.nan,inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13660\2661236613.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Quantity Ordered'].replace('Quantity Ordered',np.nan,inplace=True)

# %%
data['Quantity Ordered'] = pd.to_numeric(data['Quantity Ordered'], errors='coerce')

# Supprimer les lignes contenant des NaN
data.dropna(subset=['Quantity Ordered'], inplace=True)

# Convertir la colonne en entiers
data['Quantity Ordered'] = data['Quantity Ordered'].astype(int)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13660\2502682423.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Quantity Ordered'] = pd.to_numeric(data['Quantity Ordered'], errors='coerce')
# C:\Users\user\AppData\Local\Temp\ipykernel_13660\2502682423.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(subset=['Quantity Ordered'], inplace=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_13660\2502682423.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data['Product']=data['Product'].astype(str)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13660\174417714.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Product']=data['Product'].astype(str)

# %%
#vérification des conversions
data.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered      int32
# Price Each          float64
# Order Date           object
# Purchase Address     object
# dtype: object

# %%
# suppression des valeurs manquantes
data=data.dropna(how='all')
data.shape
# Out:
# (185950, 6)

# %%
#SUPPRESSION DES DOUBLONS

data.drop_duplicates(inplace=True)

# %%
#définition d'une fonction pour extraire la ville dans l'adresse
def city(x):
    return x.split(',')[1]

# %%
#création d'une nouvele colonne qui extrait la ville
data['city']=data['Purchase Address'].apply(city)

# %%
data['city'].value_counts()
# Out:
#  San Francisco    44662
#  Los Angeles      29564
#  New York City    24847
#  Boston           19901
#  Atlanta          14863
#  Dallas           14797
#  Seattle          14713
#  Portland         12449
#  Austin            9890
# Name: city, dtype: int64

# %%
#création d'une nouvelle colonne pour les ventes 
#ventes realisées par jour

data['Sales']=data['Quantity Ordered']*data['Price Each']

# %%
data.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered      int32
# Price Each          float64
# Order Date           object
# Purchase Address     object
# city                 object
# Sales               float64
# dtype: object

# %%
data['city'].value_counts()
# Out:
#  San Francisco    44662
#  Los Angeles      29564
#  New York City    24847
#  Boston           19901
#  Atlanta          14863
#  Dallas           14797
#  Seattle          14713
#  Portland         12449
#  Austin            9890
# Name: city, dtype: int64

# %%
#ajout des coordonnées(long,lat) à partir de la colonne city

# %%
# Définir la fonction qui prend en entrée une ville et renvoie les coordonnées correspondantes
def get_coordinates(city):
    coordinates = {
    ' San Francisco': (37.7790262, -122.419906),
    ' Los Angeles': (34.0536909, -118.242766),
    ' New York City': (40.7127281, -74.0060152),
    ' Boston': (42.3554334,-71.060511),
    ' Atlanta': (33.7489924, -84.3902644),
    ' Dallas': (32.7762719, -96.7968559),
    ' Seattle': (47.6038321, -122.330062),
    ' Portland': (45.5202471, -122.674194),
    ' Austin': (30.2711286, -97.7436995)
}
    return coordinates[city]

# %%
# Ajouter deux colonnes "latitude" et "longitude" avec les coordonnées correspondantes pour chaque ville
data['latitude'] = data['city'].apply(get_coordinates).apply(lambda x: x[0])
data['longitude'] = data['city'].apply(get_coordinates).apply(lambda x: x[1])

# %%
#vérification des colonnes créees

# %%
data
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       176558        USB-C Charging Cable                 2       11.95
# 2       176559  Bose SoundSport Headphones                 1       99.99
# 3       176560                Google Phone                 1      600.00
# 4       176560            Wired Headphones                 1       11.99
# 5       176561            Wired Headphones                 1       11.99
# ...        ...                         ...               ...         ...
# 11681   259353      AAA Batteries (4-pack)                 3        2.99
# 11682   259354                      iPhone                 1      700.00
# 11683   259355                      iPhone                 1      700.00
# 11684   259356      34in Ultrawide Monitor                 1      379.99
# 11685   259357        USB-C Charging Cable                 1       11.95
#
#            Order Date                         Purchase Address  \
# ...

# %%
data.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered      int32
# Price Each          float64
# Order Date           object
# Purchase Address     object
# city                 object
# Sales               float64
# latitude            float64
# longitude           float64
# dtype: object

# %% [markdown]
# ## Exporter les données pour des visualisations sur Tableau

# %%
data.to_csv('bd.csv', index=False)

# %%
#correlation entre prix et quantités commandées
#geocodage des adresse
#creer une nouvelle variable sales
#tableai viz
#

# %% [markdown]
# ## Visualisations

# %% [markdown]
# ### étude de la relation entre le prix d'un produit et ses ventes

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Sélectionner les variables d'intérêt
X = data[['Price Each']]
y = data['Sales']

# Créer un modèle de régression linéaire
model = LinearRegression()

# Entraîner le modèle sur les données
model.fit(X, y)

# Tracer le nuage de points
plt.scatter(X, y)

# Tracer la droite de régression
x_values = np.linspace(X.min(), X.max(), 100)
y_values = model.predict(x_values.reshape(-1, 1))
plt.plot(x_values, y_values, color='red')

# Ajouter un titre et des étiquettes d'axe
plt.title("Relation entre le prix d'un produit et les ventes")
plt.xlabel("Prix")
plt.ylabel("ventes")

# Afficher le graphique
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Calculer le coefficient de corrélation
corr = np.corrcoef(X.T, y.T)[0, 1]
print("Le coefficient de corrélation est :", corr)

# Calculer le coefficient de détermination (R2)
R2 = model.score(X, y)
print("Le coefficient de détermination est :", R2)
# Out:
# Le coefficient de corrélation est : 0.9992023184439915
# Le coefficient de détermination est : 0.998405273183847

# %%
# Extraire les coefficients d'interception et de pente du modèle
intercept = model.intercept_
slope = model.coef_[0]

# Construire l'équation de régression
equation = "y = {:.2f} + {:.2f}x".format(intercept, slope)

# Afficher l'équation de régression
print("Equation de régression : ", equation)
# Out:
# Equation de régression :  y = 1.14 + 1.00x

# %% [markdown]
# ### Interpretations

# %% [markdown]
# #### R et R2
#
# - Le coefficient de corrélation est très proche de 1, ce qui suggère une forte corrélation positive linéaire entre le
# prix d'un produit et les ventes. Cela signifie que lorsque le prix d'un produit augmente, les ventes ont tendance à
# augmenter également.
#
#
# - Le coefficient de détermination, également appelé R2, mesure la proportion de la variance totale
# des ventes qui est expliquée par la relation linéaire avec le prix. Un coefficient de détermination de 0,9984
# indique que la relation linéaire entre le prix et les ventes explique 99,84% de la variance totale des ventes.
# En d'autres termes, le modèle de régression linéaire ajusté sur ces données est très précis pour prédire les ventes
# en fonction du prix.
#
# #### Equation y=a+ b*x (y = 1.14 + 1.00x)
#
# - L'interception (valeur de "a") est de 1.14, ce qui signifie que si le prix d'un produit est nul(0 dollar), on peut s'attendre à vendre 1.14 dollars de ce produit. Cela peut sembler absurde dans ce contexte, car il est peu probable qu'un produit soit vendu gratuitement, mais cela peut être interprété comme la valeur minimale de vente pour ce produit, même s'il est vendu à un prix très bas.
#
# - La pente (valeur de "b") est de 1.00, ce qui signifie que pour chaque unité d'augmentation du prix d'un produit, on peut s'attendre à une augmentation de 1.00 dollar des ventes de ce produit. Cela indique une forte corrélation positive entre le prix et les ventes, comme cela a été évoqué précédemment.

# %% [markdown]
# ### Avec ces résultats, l'entreprise peut tirer plusieurs informations utiles :

# %% [markdown]
# - Corrélation positive forte : Les coefficients de corrélation et de détermination sont très proches de 1, ce qui indique une forte corrélation positive entre le prix et les ventes. Cela signifie que l'entreprise peut s'attendre à des ventes plus élevées si elle augmente les prix de ses produits.
#
#
# - Équation de régression : L'équation de régression fournit une estimation de la relation entre le prix et les ventes. L'entreprise peut utiliser cette équation pour prédire les ventes en fonction des prix, et ainsi ajuster les prix de manière appropriée pour maximiser les ventes et les profits.
#
#
# - Valeurs minimales de vente : L'interception de l'équation de régression donne la valeur minimale de vente pour ce produit, même s'il est vendu à un prix très bas. Cette information peut être utile pour déterminer le prix minimum que l'entreprise doit facturer pour couvrir les coûts de production.
#
#
# En utilisant ces informations, l'entreprise peut prendre des décisions plus éclairées sur les prix de ses produits pour maximiser les ventes et les profits.

# %% [markdown]
# ### Visualisations sur tableau

# %% [markdown]
# Lien des Dashboards sur Tableau Public
#
# - [Rapport(1) des ventes de 2019](https://public.tableau.com/app/profile/ornella.fogue/viz/AnalysisofSales_16825099820010/Rapport1desventesde2019)
#
# - [Rapport(2) des ventes de 2019](https://public.tableau.com/app/profile/ornella.fogue/viz/AnalysisofSales_16825099820010/Rapport2ventes2019)

# %% [markdown]
# ![Rapport%201%20des%20ventes%20de%202019.png](attachment:Rapport%201%20des%20ventes%20de%202019.png)

# %% [markdown]
# ![Rapport%202%20ventes%202019.png](attachment:Rapport%202%20ventes%202019.png)

# %% [markdown]
# ### Interpertation  et informations utiles pour l'entreprise(Prise de décision)

# %% [markdown]
# #### Rapport 1

# %% [markdown]
# - D'après les deux premiers graphes, on remarque que les 2 produits qui ont fait le moins de chiffre d'affaires(AAA Batteries et AA Batteries (4 pack)) sont ceux qui ont été le plus commandés en quantité. Cela s'explique par le fait que ces produits peuvent avoir des prix plus bas, des marges bénéficiaires plus faibles, ou ne pas avoir bénéficié d'une promotion aussi importante que les autres produits qui ont généré plus de ventes. De plus, les clients peuvent acheter plusieurs produits différents dans la même commande, ce qui peut également affecter le chiffre d'affaires total. Ces informations peuvent aider l'entreprise  à optimiser les marges bénéficiaires(les produits qui ont une forte demande en termes de quantité mais qui génèrent des marges bénéficiaires plus faibles peuvent être réévalués), à comprendre les comportements d'achat des clients(analyser les données d'achat des clients pour comprendre leur comportement et identifier les produits qu'ils achètent régulièrement ensemble;cela peut aider à identifier les opportunités de vente croisée et de vente incitative pour augmenter le chiffre d'affaires total) et à diversifier la gamme de produits( évaluer la gamme de produits et diversifier l'offre de produits pour répondre à différents segments de marché) pour améliorer le chiffre d'affaires total.
#
#
#
#
#
# - D'après la carte, San Francisco est le marché le plus important de l'entreprise,elle peut donc envisager d'investir davantage dans cette ville pour augmenter encore plus les ventes. Cela pourrait inclure l'ouverture de nouveaux magasins ou bureaux, l'augmentation des efforts de marketing dans cette région, ou l'ajout de nouveaux produits ou services qui répondent spécifiquement à la demande de San Francisco. Cependant, il est également important de considérer les autres villes et leurs performances de vente. L'entreprise pourrait également envisager de renforcer sa présence dans les autres villes où les ventes sont plus faibles pour accroître sa portée et sa part de marché globale.

# %% [markdown]
# #### Rapport 2

# %% [markdown]
# - D'apres le 1er graphe,les ventes ont explosé en octobre et décembre, cela  s'explique comme une augmentation de la demande pendant les périodes de fêtes. L'entreprise peut utiliser ces informations pour planifier les niveaux de stock pendant les mois de pointe pour s'assurer de répondre à la demande. Si  les ventes seront plus élevées en octobre et décembre, elle doit ajuster son stock pour s'assurer qu'elle a suffisamment de produits pour répondre à la demande.
#
#
# - D'apres le 2ème graphe, on peut constater que l'heure à laquelle les ventes explose(le nombre de commandes respectivement) pour chaque ville se situe entre 12h et 19h. ces heures peuvent etre les meilleurs moments pour faire des promotions: lancer une publicité par exemeple. L'entreprise pourra auussi Optimiser ses canaux de vente : elle pourra utiliser ces informations pour optimiser les canaux de vente. Si la majorité des commandes se font via une certaine plateforme de vente en ligne, elle peut se concentrer davantage sur ce canal et optimiser sa présence en ligne pour stimuler les ventes pendant les heures de pointe.

# %%
C:/Users/user/projet perso
